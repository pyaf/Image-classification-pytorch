# %%
import pdb

import torch
from torch import nn
import cv2
import os
from PIL import Image
from skimage import io, transform
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd
from torchvision.datasets.folder import pil_loader
import random
import numpy as np
from torchsummary import summary
import pretrainedmodels
from sklearn.model_selection import KFold, StratifiedKFold


from albumentations import torch as AT
os.environ['CUDA_VISIBLE_DEVICES']=""
# %matplotlib inline

# %%
np.eye

# %%
# !ls data
# Out:
# sample_submission.csv  test  train  train_labels.csv

# %%
train_df = pd.read_csv('data/train_labels.csv')
test_df = pd.read_csv('data/sample_submission.csv')

# %%
test_df.shape
# Out:
# (57458, 2)

# %%
train_df.head()
# Out:
#                                          id  label
# 0  f38a6374c348f90b587e046aac6079959adf3835      0
# 1  c18f2d887b7ae4f6742ee445113fa1aef383ed77      1
# 2  755db6279dae599ebb4d39a9123cce439965282d      0
# 3  bc3f0c64fb968ff4a8bd33af6971ecae77c75e08      0
# 4  068aba587a4950175d04c680d38943fd488d6a9d      0

# %%
train_df.at[0, 'label'] = 1

# %%
kfold = StratifiedKFold(20, shuffle=True, random_state=69)

# %%
kfold.split(train_df['id'], train_df['label'])
# Out:
# <generator object _BaseKFold.split at 0x7fe662ddc8b8>

# %%
train_df.iloc[test]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7b728837b751> in <module>
# ----> 1 train_df.iloc[test]
#
# NameError: name 'test' is not defined

# %%
train_df.head()
# Out:
#                                          id  label
# 0  f38a6374c348f90b587e046aac6079959adf3835      1
# 1  c18f2d887b7ae4f6742ee445113fa1aef383ed77      1
# 2  755db6279dae599ebb4d39a9123cce439965282d      0
# 3  bc3f0c64fb968ff4a8bd33af6971ecae77c75e08      0
# 4  068aba587a4950175d04c680d38943fd488d6a9d      0

# %%
train_df.info(), test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220025 entries, 0 to 220024
# Data columns (total 2 columns):
# id       220025 non-null object
# label    220025 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 3.4+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57458 entries, 0 to 57457
# Data columns (total 2 columns):
# id       57458 non-null object
# label    57458 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 897.9+ KB
# (None, None)

# %%
# %%time
img = mpimg.imread('data/train/00001b2b5609af42ab0ab276dd4cd41c3e7745b5.tif')
# Out:
# CPU times: user 5.96 ms, sys: 0 ns, total: 5.96 ms
# Wall time: 17.8 ms

# %%
timeit mpimg.imread('data/train/00001b2b5609af42ab0ab276dd4cd41c3e7745b5.tif')
# Out:
# 183 µs ± 1.13 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
timeit pil_loader('data/train/00001b2b5609af42ab0ab276dd4cd41c3e7745b5.tif')

# %%
timeit cv2.imread('data/train/00001b2b5609af42ab0ab276dd4cd41c3e7745b5.tif', flags=cv2.IMREAD_COLOR)

# %%
timeit io.imread("data/train/00001b2b5609af42ab0ab276dd4cd41c3e7745b5.tif")

# %%
img = torch.Tensor(img)

# %%
img.flip?

# %%
torch.flip?

# %% [markdown]
# ##### use cv2.imread for reading images

# %%
img.shape

# %%
plt.imshow(img)

# %%
# plot some random training images with their ground truth labels
i = random.choice(range(train_df.shape[0]))
img = mpimg.imread('data/train/' + train_df.iloc[i]['id'] + '.tif')
plt.imshow(img)
plt.title(train_df.iloc[i]['label'])
plt.show()

# %%
train_df['label'].value_counts()

# %%
train_df['label'].hist

# %%
img = mpimg.imread('data/train/dd6dfed324f9fcb6f93f46f32fc800f2ec196be2.tif')
plt.imshow(img)
plt.show();
aug_img = train_aug(image=img)
plt.imshow(aug_img['image'])
plt.show();

# %% [markdown]
# #### Dataloader analysis

# %%
from dataloader import get_dataloader

# %%
def unnormalize(img):
    mean = torch.as_tensor([0.485, 0.456, 0.406])
    std = torch.as_tensor([0.229, 0.224, 0.225])
    #return (img * std) + mean
    for t, m, s in zip(img, mean, std):    
        t.mul_(s).add_(m)
    return img

# %%
phase = "train"
dataloader = get_dataloader(phase)

# %%
batch = next(iter(dataloader))

# %%
images, labels = batch
labels

# %%
# plot some random training images with their ground truth labels
i = random.choice(range(len(images)))
img = images[i].clone()
img = unnormalize(img)
plt.imshow(img.permute(1, 2, 0))
plt.title(labels[i].item())
plt.show()

# %%
mean = torch.as_tensor([0.485, 0.456, 0.406])
std = torch.as_tensor([0.229, 0.224, 0.225])
#return (img * std) + mean
#return img.mul_(std).add_(mean)
labels[i].item()

# %%
mean, std, mean.shape, std.shape

# %% [raw]
# Model testing

# %%
import pretrainedmodels
pretrainedmodels.model_names
# Out:
# ['fbresnet152',
#  'bninception',
#  'resnext101_32x4d',
#  'resnext101_64x4d',
#  'inceptionv4',
#  'inceptionresnetv2',
#  'alexnet',
#  'densenet121',
#  'densenet169',
#  'densenet201',
#  'densenet161',
#  'resnet18',
#  'resnet34',
#  'resnet50',
#  'resnet101',
#  'resnet152',
#  'inceptionv3',
#  'squeezenet1_0',
#  'squeezenet1_1',
#  'vgg11',
#  'vgg11_bn',
#  'vgg13',
#  'vgg13_bn',
#  'vgg16',
#  'vgg16_bn',
#  'vgg19_bn',
#  'vgg19',
#  'nasnetamobile',
#  'nasnetalarge',
#  'dpn68',
#  'dpn68b',
#  'dpn92',
#  'dpn98',
#  'dpn131',
#  'dpn107',
#  'xception',
#  'senet154',
#  'se_resnet50',
#  'se_resnet101',
#  'se_resnet152',
#  'se_resnext50_32x4d',
#  'se_resnext101_32x4d',
#  'cafferesnet101',
#  'pnasnet5large',
#  'polynet']

# %%
pretrainedmodels.resnext101_32x4d()
# Out:
# Downloading: "http://data.lip6.fr/cadene/pretrainedmodels/resnext101_32x4d-29e315fa.pth" to /home/ags/.torch/models/resnext101_32x4d-29e315fa.pth
# 177332805it [00:12, 13759514.87it/s]
# ResNeXt101_32x4d(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (1): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (2): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#     )
#     (5): Sequential(
#       (0): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (1): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (2): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (3): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#     )
#     (6): Sequential(
#       (0): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (1): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (2): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (3): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (4): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (5): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (6): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (7): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (8): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (9): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (10): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (11): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (12): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (13): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (14): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (15): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (16): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (17): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (18): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (19): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (20): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (21): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (22): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#     )
#     (7): Sequential(
#       (0): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (1): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#       (2): Sequential(
#         (0): LambdaMap(
#           (0): Sequential(
#             (0): Sequential(
#               (0): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#               (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (5): ReLU()
#             )
#             (1): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): Lambda()
#         )
#         (1): LambdaReduce()
#         (2): ReLU()
#       )
#     )
#   )
#   (avg_pool): AvgPool2d(kernel_size=(7, 7), stride=(1, 1), padding=0)
#   (last_linear): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
# model_name='se_resnext50_32x4d'
model_name= "resnext101_32x4d"#'nasnetamobile'

model = pretrainedmodels.__dict__[model_name](num_classes=1000)

# %%
#model.features

# %%
blocks = list(model.children())
# blocks[:-3]
model
# Out:
# NASNetAMobile(
#   (conv0): Sequential(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (cell_stem_0): CellStem0(
#     (conv_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(32, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(11, 11, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=11, bias=False)
#         (pointwise_conv2d): Conv2d(11, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(11, 11, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=11, bias=False)
#         (pointwise_conv2d): Conv2d(11, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_right): BranchSeparablesStem(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(32, 32, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=32, bias=False)
#         (pointwise_conv2d): Conv2d(32, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(11, 11, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=11, bias=False)
#         (pointwise_conv2d): Conv2d(11, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_left): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (comb_iter_1_right): BranchSeparablesStem(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(32, 32, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=32, bias=False)
#         (pointwise_conv2d): Conv2d(32, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(11, 11, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=11, bias=False)
#         (pointwise_conv2d): Conv2d(11, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_2_left): AvgPool2d(kernel_size=3, stride=2, padding=1)
#     (comb_iter_2_right): BranchSeparablesStem(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(32, 32, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=32, bias=False)
#         (pointwise_conv2d): Conv2d(32, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(11, 11, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=11, bias=False)
#         (pointwise_conv2d): Conv2d(11, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_3_right): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_4_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(11, 11, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=11, bias=False)
#         (pointwise_conv2d): Conv2d(11, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(11, 11, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=11, bias=False)
#         (pointwise_conv2d): Conv2d(11, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_4_right): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (cell_stem_1): CellStem1(
#     (conv_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(44, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU()
#     (path_1): Sequential(
#       (avgpool): AvgPool2d(kernel_size=1, stride=2, padding=0)
#       (conv): Conv2d(32, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (path_2): ModuleList(
#       (pad): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       (avgpool): AvgPool2d(kernel_size=1, stride=2, padding=0)
#       (conv): Conv2d(32, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (final_path_bn): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (comb_iter_0_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(22, 22, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=22, bias=False)
#         (pointwise_conv2d): Conv2d(22, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(22, 22, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=22, bias=False)
#         (pointwise_conv2d): Conv2d(22, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(22, 22, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=22, bias=False)
#         (pointwise_conv2d): Conv2d(22, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(22, 22, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=22, bias=False)
#         (pointwise_conv2d): Conv2d(22, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_left): MaxPoolPad(
#       (pad): ZeroPad2d(padding=(1, 0, 1, 0), value=0.0)
#       (pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     )
#     (comb_iter_1_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(22, 22, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=22, bias=False)
#         (pointwise_conv2d): Conv2d(22, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(22, 22, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=22, bias=False)
#         (pointwise_conv2d): Conv2d(22, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_2_left): AvgPoolPad(
#       (pad): ZeroPad2d(padding=(1, 0, 1, 0), value=0.0)
#       (pool): AvgPool2d(kernel_size=3, stride=2, padding=1)
#     )
#     (comb_iter_2_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(22, 22, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=22, bias=False)
#         (pointwise_conv2d): Conv2d(22, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(22, 22, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=22, bias=False)
#         (pointwise_conv2d): Conv2d(22, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_3_right): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_4_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(22, 22, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=22, bias=False)
#         (pointwise_conv2d): Conv2d(22, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(22, 22, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=22, bias=False)
#         (pointwise_conv2d): Conv2d(22, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_4_right): MaxPoolPad(
#       (pad): ZeroPad2d(padding=(1, 0, 1, 0), value=0.0)
#       (pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     )
#   )
#   (cell_0): FirstCell(
#     (conv_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(88, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU()
#     (path_1): Sequential(
#       (avgpool): AvgPool2d(kernel_size=1, stride=2, padding=0)
#       (conv): Conv2d(44, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (path_2): ModuleList(
#       (pad): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       (avgpool): AvgPool2d(kernel_size=1, stride=2, padding=0)
#       (conv): Conv2d(44, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (final_path_bn): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (comb_iter_0_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_2_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_right): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_4_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (cell_1): NormalCell(
#     (conv_prev_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(88, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(264, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_2_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_right): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_4_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (cell_2): NormalCell(
#     (conv_prev_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(264, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(264, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_2_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_right): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_4_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (cell_3): NormalCell(
#     (conv_prev_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(264, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(264, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_2_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_right): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_4_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(44, 44, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=44, bias=False)
#         (pointwise_conv2d): Conv2d(44, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(44, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (reduction_cell_0): ReductionCell0(
#     (conv_prev_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(264, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(264, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_left): BranchSeparablesReduction(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (padding): ZeroPad2d(padding=(1, 0, 1, 0), value=0.0)
#     )
#     (comb_iter_0_right): BranchSeparablesReduction(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (padding): ZeroPad2d(padding=(1, 0, 1, 0), value=0.0)
#     )
#     (comb_iter_1_left): MaxPoolPad(
#       (pad): ZeroPad2d(padding=(1, 0, 1, 0), value=0.0)
#       (pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     )
#     (comb_iter_1_right): BranchSeparablesReduction(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (padding): ZeroPad2d(padding=(1, 0, 1, 0), value=0.0)
#     )
#     (comb_iter_2_left): AvgPoolPad(
#       (pad): ZeroPad2d(padding=(1, 0, 1, 0), value=0.0)
#       (pool): AvgPool2d(kernel_size=3, stride=2, padding=1)
#     )
#     (comb_iter_2_right): BranchSeparablesReduction(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (padding): ZeroPad2d(padding=(1, 0, 1, 0), value=0.0)
#     )
#     (comb_iter_3_right): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_4_left): BranchSeparablesReduction(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (padding): ZeroPad2d(padding=(1, 0, 1, 0), value=0.0)
#     )
#     (comb_iter_4_right): MaxPoolPad(
#       (pad): ZeroPad2d(padding=(1, 0, 1, 0), value=0.0)
#       (pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     )
#   )
#   (cell_6): FirstCell(
#     (conv_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(352, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU()
#     (path_1): Sequential(
#       (avgpool): AvgPool2d(kernel_size=1, stride=2, padding=0)
#       (conv): Conv2d(264, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (path_2): ModuleList(
#       (pad): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       (avgpool): AvgPool2d(kernel_size=1, stride=2, padding=0)
#       (conv): Conv2d(264, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (final_path_bn): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (comb_iter_0_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_2_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_right): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_4_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (cell_7): NormalCell(
#     (conv_prev_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(352, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_2_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_right): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_4_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (cell_8): NormalCell(
#     (conv_prev_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (pointwise_conv2d): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(88, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_2_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_right): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_4_left): BranchSeparables(
#       (relu): ReLU()
# ...
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_2_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_right): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_4_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (cell_13): NormalCell(
#     (conv_prev_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(704, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_2_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_right): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_4_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (cell_14): NormalCell(
#     (conv_prev_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_2_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_right): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_4_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (cell_15): NormalCell(
#     (conv_prev_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_1x1): Sequential(
#       (relu): ReLU()
#       (conv): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_0_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_1_right): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (comb_iter_2_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_left): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_3_right): AvgPool2d(kernel_size=3, stride=1, padding=1)
#     (comb_iter_4_left): BranchSeparables(
#       (relu): ReLU()
#       (separable_1): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_1): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (separable_2): SeparableConv2d(
#         (depthwise_conv2d): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (pointwise_conv2d): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn_sep_2): BatchNorm2d(176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (relu): ReLU()
#   (avg_pool): AvgPool2d(kernel_size=7, stride=1, padding=0)
#   (dropout): Dropout(p=0.5)
#   (last_linear): Linear(in_features=1056, out_features=1000, bias=True)
# )

# %%
model.layer0.parameters()
model.layer1.parameters()
model.layer2.parameters()
model.layer3.parameters()
model.layer4.parameters()
#list(model.children())[0]#.parameterss()
model.avg_pool

# %%
[
    {"params": model.layer0.paramters()},
    {"params": model.layer1.paramters()},
    {"params": model.layer2.paramters()},
    {"params": model.layer3.paramters()},
    {"params": model.layer4.paramters()},
    {"params": model.avg_pool.paramters()},
    {"params": model.last_linear.parameters(), "lr": 3e-5}
], lr=3e-5*0.001,

import torch

# %%
class classifier(torch.nn.Module):
    def __init__(self):
        self.gmp = torch.nn.functional.max_pool2d()
        self.aap = torch.nn.functional.adaptive_avg_pool2d()
        self.conc = torch.nn.conc()
        self.dp = torch.nn.Dropout(0.5)
        self.lin = torch.nn.Linear(1056, 1, bias=True) 
    def forward(self, x):
        pdb.set_trace()
        out1 = self.gmp(x)
        out2 = self.aap(x)
        flat = x.view(x.size[0], -1)
        out = self.conc(out1, out2, flat)
        out = self.dp(out)
        out = self.lin(out)
        return out

# %%
blocks = list(model.children())
head = torch.nn.Sequential(*list(model.children())[:-3])
# model._modules['layer0'] = head
#model._modules['avg_pool'] = torch.nn.AvgPool2d(kernel_size=5, stride=1, padding=0) 
#model._modules['avg_pool'] = torch.nn.Sequential(*[torch.nn.ConstantPad2d((0,1,0,1), 0), torch.nn.AvgPool2d(kernel_size=7, stride=1, padding=0)])
# model._modules['avg_pool'] = torch.nn.Sequential(torch.nn.AdaptiveAvgPool2d((1, 1)))
# model._modules['last_linear'] = torch.nn.Linear(in_features=2048, out_features=1, bias=True)
# model._modules['last_layer'] = classifier

# %%
torch.nn.AdaptiveAvgPool2d?

# %%
#head.parameters()
#for block in blocks:
base = list(blocks[0].children())[:-1] + blocks[1:-2]
torch.nn.Sequential(*base)
torch.nn.Dropout?
#    print(block)
#    print('*'*100)

# %%
torch.nn.Linear?

# %%
#blocks[0] = head

# %%
#blocks[-1] = torch.nn.Linear(in_features=2048, out_features=1, bias=True)

# %%
#model = torch.nn.Sequential(*blocks)

# %%
#model._modules

# %%
#img = torch.Tensor(1, 3, 224, 224)#.to('cuda')
img = torch.Tensor(1, 3, 112, 112)
img = torch.Tensor(1, 3, 96, 96)

# %%
out = model(img)

print(out)
# Out:
# tensor([[-0.2230]], grad_fn=<AddmmBackward>)

# %%
x = None
for param in model.children():
    
    print(param)
    if x is None:
        x = param(img)
    else:
        x = param(x)
    print(x.shape)
# Out:
# Sequential(
#   (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#   (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# torch.Size([1, 32, 47, 47])
# CellStem0(
#   (conv_1x1): Sequential(
#     (relu): ReLU()
#     (conv): Conv2d(32, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (comb_iter_0_left): BranchSeparables(
#     (relu): ReLU()
#     (separable_1): SeparableConv2d(
#       (depthwise_conv2d): Conv2d(11, 11, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=11, bias=False)
#       (pointwise_conv2d): Conv2d(11, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn_sep_1): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (separable_2): SeparableConv2d(
#       (depthwise_conv2d): Conv2d(11, 11, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=11, bias=False)
#       (pointwise_conv2d): Conv2d(11, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn_sep_2): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (comb_iter_0_right): BranchSeparablesStem(
#     (relu): ReLU()
#     (separable_1): SeparableConv2d(
#       (depthwise_conv2d): Conv2d(32, 32, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=32, bias=False)
#       (pointwise_conv2d): Conv2d(32, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn_sep_1): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (separable_2): SeparableConv2d(
#       (depthwise_conv2d): Conv2d(11, 11, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=11, bias=False)
#       (pointwise_conv2d): Conv2d(11, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn_sep_2): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (comb_iter_1_left): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (comb_iter_1_right): BranchSeparablesStem(
#     (relu): ReLU()
#     (separable_1): SeparableConv2d(
#       (depthwise_conv2d): Conv2d(32, 32, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=32, bias=False)
#       (pointwise_conv2d): Conv2d(32, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn_sep_1): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (separable_2): SeparableConv2d(
#       (depthwise_conv2d): Conv2d(11, 11, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=11, bias=False)
#       (pointwise_conv2d): Conv2d(11, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn_sep_2): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (comb_iter_2_left): AvgPool2d(kernel_size=3, stride=2, padding=1)
#   (comb_iter_2_right): BranchSeparablesStem(
#     (relu): ReLU()
#     (separable_1): SeparableConv2d(
#       (depthwise_conv2d): Conv2d(32, 32, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=32, bias=False)
#       (pointwise_conv2d): Conv2d(32, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn_sep_1): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (separable_2): SeparableConv2d(
#       (depthwise_conv2d): Conv2d(11, 11, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=11, bias=False)
#       (pointwise_conv2d): Conv2d(11, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn_sep_2): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (comb_iter_3_right): AvgPool2d(kernel_size=3, stride=1, padding=1)
#   (comb_iter_4_left): BranchSeparables(
#     (relu): ReLU()
#     (separable_1): SeparableConv2d(
#       (depthwise_conv2d): Conv2d(11, 11, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=11, bias=False)
#       (pointwise_conv2d): Conv2d(11, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn_sep_1): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (separable_2): SeparableConv2d(
#       (depthwise_conv2d): Conv2d(11, 11, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=11, bias=False)
#       (pointwise_conv2d): Conv2d(11, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn_sep_2): BatchNorm2d(11, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (comb_iter_4_right): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# )
# torch.Size([1, 44, 24, 24])
# CellStem1(
#   (conv_1x1): Sequential(
#     (relu): ReLU()
#     (conv): Conv2d(44, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (relu): ReLU()
#   (path_1): Sequential(
#     (avgpool): AvgPool2d(kernel_size=1, stride=2, padding=0)
#     (conv): Conv2d(32, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (path_2): ModuleList(
#     (pad): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#     (avgpool): AvgPool2d(kernel_size=1, stride=2, padding=0)
#     (conv): Conv2d(32, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (final_path_bn): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (comb_iter_0_left): BranchSeparables(
#     (relu): ReLU()
#     (separable_1): SeparableConv2d(
#       (depthwise_conv2d): Conv2d(22, 22, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=22, bias=False)
#       (pointwise_conv2d): Conv2d(22, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn_sep_1): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (separable_2): SeparableConv2d(
#       (depthwise_conv2d): Conv2d(22, 22, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=22, bias=False)
#       (pointwise_conv2d): Conv2d(22, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn_sep_2): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (comb_iter_0_right): BranchSeparables(
#     (relu): ReLU()
#     (separable_1): SeparableConv2d(
#       (depthwise_conv2d): Conv2d(22, 22, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=22, bias=False)
#       (pointwise_conv2d): Conv2d(22, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn_sep_1): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (separable_2): SeparableConv2d(
#       (depthwise_conv2d): Conv2d(22, 22, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=22, bias=False)
#       (pointwise_conv2d): Conv2d(22, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn_sep_2): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (comb_iter_1_left): MaxPoolPad(
#     (pad): ZeroPad2d(padding=(1, 0, 1, 0), value=0.0)
#     (pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (comb_iter_1_right): BranchSeparables(
#     (relu): ReLU()
#     (separable_1): SeparableConv2d(
#       (depthwise_conv2d): Conv2d(22, 22, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=22, bias=False)
#       (pointwise_conv2d): Conv2d(22, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn_sep_1): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (separable_2): SeparableConv2d(
#       (depthwise_conv2d): Conv2d(22, 22, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=22, bias=False)
#       (pointwise_conv2d): Conv2d(22, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn_sep_2): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (comb_iter_2_left): AvgPoolPad(
#     (pad): ZeroPad2d(padding=(1, 0, 1, 0), value=0.0)
#     (pool): AvgPool2d(kernel_size=3, stride=2, padding=1)
#   )
#   (comb_iter_2_right): BranchSeparables(
#     (relu): ReLU()
#     (separable_1): SeparableConv2d(
#       (depthwise_conv2d): Conv2d(22, 22, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=22, bias=False)
#       (pointwise_conv2d): Conv2d(22, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn_sep_1): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (separable_2): SeparableConv2d(
#       (depthwise_conv2d): Conv2d(22, 22, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=22, bias=False)
#       (pointwise_conv2d): Conv2d(22, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn_sep_2): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (comb_iter_3_right): AvgPool2d(kernel_size=3, stride=1, padding=1)
#   (comb_iter_4_left): BranchSeparables(
#     (relu): ReLU()
#     (separable_1): SeparableConv2d(
#       (depthwise_conv2d): Conv2d(22, 22, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=22, bias=False)
#       (pointwise_conv2d): Conv2d(22, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn_sep_1): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (separable_2): SeparableConv2d(
#       (depthwise_conv2d): Conv2d(22, 22, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=22, bias=False)
#       (pointwise_conv2d): Conv2d(22, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn_sep_2): BatchNorm2d(22, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (comb_iter_4_right): MaxPoolPad(
#     (pad): ZeroPad2d(padding=(1, 0, 1, 0), value=0.0)
#     (pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
# )
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-71482f4b9a9a> in <module>
#       6         x = param(img)
#       7     else:
# ----> 8         x = param(x)
#       9     print(x.shape)
#
# ~/miniconda3/envs/ML/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# TypeError: forward() missing 1 required positional argument: 'x_stem_0'

# %%
# summary(model, input_size=(3, 96, 96))
# summary(model, input_size=(3, 112, 112))
summary(model.features, input_size=(3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5          [-1, 128, 56, 56]           8,192
#        BatchNorm2d-6          [-1, 128, 56, 56]             256
#               ReLU-7          [-1, 128, 56, 56]               0
#             Conv2d-8          [-1, 128, 56, 56]           4,608
#        BatchNorm2d-9          [-1, 128, 56, 56]             256
#              ReLU-10          [-1, 128, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          32,768
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#            Conv2d-13          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-14          [-1, 256, 56, 56]             512
#              ReLU-15          [-1, 256, 56, 56]               0
#            Conv2d-16          [-1, 128, 56, 56]          32,768
#       BatchNorm2d-17          [-1, 128, 56, 56]             256
#              ReLU-18          [-1, 128, 56, 56]               0
#            Conv2d-19          [-1, 128, 56, 56]           4,608
#       BatchNorm2d-20          [-1, 128, 56, 56]             256
#              ReLU-21          [-1, 128, 56, 56]               0
#            Conv2d-22          [-1, 256, 56, 56]          32,768
#       BatchNorm2d-23          [-1, 256, 56, 56]             512
#              ReLU-24          [-1, 256, 56, 56]               0
#            Conv2d-25          [-1, 128, 56, 56]          32,768
#       BatchNorm2d-26          [-1, 128, 56, 56]             256
#              ReLU-27          [-1, 128, 56, 56]               0
#            Conv2d-28          [-1, 128, 56, 56]           4,608
#       BatchNorm2d-29          [-1, 128, 56, 56]             256
#              ReLU-30          [-1, 128, 56, 56]               0
#            Conv2d-31          [-1, 256, 56, 56]          32,768
#       BatchNorm2d-32          [-1, 256, 56, 56]             512
#              ReLU-33          [-1, 256, 56, 56]               0
#            Conv2d-34          [-1, 256, 56, 56]          65,536
#       BatchNorm2d-35          [-1, 256, 56, 56]             512
#              ReLU-36          [-1, 256, 56, 56]               0
#            Conv2d-37          [-1, 256, 28, 28]          18,432
#       BatchNorm2d-38          [-1, 256, 28, 28]             512
#              ReLU-39          [-1, 256, 28, 28]               0
#            Conv2d-40          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-41          [-1, 512, 28, 28]           1,024
#            Conv2d-42          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-43          [-1, 512, 28, 28]           1,024
#              ReLU-44          [-1, 512, 28, 28]               0
#            Conv2d-45          [-1, 256, 28, 28]         131,072
#       BatchNorm2d-46          [-1, 256, 28, 28]             512
#              ReLU-47          [-1, 256, 28, 28]               0
#            Conv2d-48          [-1, 256, 28, 28]          18,432
#       BatchNorm2d-49          [-1, 256, 28, 28]             512
#              ReLU-50          [-1, 256, 28, 28]               0
#            Conv2d-51          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-52          [-1, 512, 28, 28]           1,024
#              ReLU-53          [-1, 512, 28, 28]               0
#            Conv2d-54          [-1, 256, 28, 28]         131,072
#       BatchNorm2d-55          [-1, 256, 28, 28]             512
#              ReLU-56          [-1, 256, 28, 28]               0
#            Conv2d-57          [-1, 256, 28, 28]          18,432
#       BatchNorm2d-58          [-1, 256, 28, 28]             512
#              ReLU-59          [-1, 256, 28, 28]               0
#            Conv2d-60          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-61          [-1, 512, 28, 28]           1,024
#              ReLU-62          [-1, 512, 28, 28]               0
#            Conv2d-63          [-1, 256, 28, 28]         131,072
#       BatchNorm2d-64          [-1, 256, 28, 28]             512
#              ReLU-65          [-1, 256, 28, 28]               0
#            Conv2d-66          [-1, 256, 28, 28]          18,432
#       BatchNorm2d-67          [-1, 256, 28, 28]             512
#              ReLU-68          [-1, 256, 28, 28]               0
#            Conv2d-69          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-70          [-1, 512, 28, 28]           1,024
#              ReLU-71          [-1, 512, 28, 28]               0
#            Conv2d-72          [-1, 512, 28, 28]         262,144
#       BatchNorm2d-73          [-1, 512, 28, 28]           1,024
#              ReLU-74          [-1, 512, 28, 28]               0
#            Conv2d-75          [-1, 512, 14, 14]          73,728
#       BatchNorm2d-76          [-1, 512, 14, 14]           1,024
#              ReLU-77          [-1, 512, 14, 14]               0
#            Conv2d-78         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-79         [-1, 1024, 14, 14]           2,048
#            Conv2d-80         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-81         [-1, 1024, 14, 14]           2,048
#              ReLU-82         [-1, 1024, 14, 14]               0
#            Conv2d-83          [-1, 512, 14, 14]         524,288
#       BatchNorm2d-84          [-1, 512, 14, 14]           1,024
#              ReLU-85          [-1, 512, 14, 14]               0
#            Conv2d-86          [-1, 512, 14, 14]          73,728
#       BatchNorm2d-87          [-1, 512, 14, 14]           1,024
#              ReLU-88          [-1, 512, 14, 14]               0
#            Conv2d-89         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-90         [-1, 1024, 14, 14]           2,048
#              ReLU-91         [-1, 1024, 14, 14]               0
#            Conv2d-92          [-1, 512, 14, 14]         524,288
#       BatchNorm2d-93          [-1, 512, 14, 14]           1,024
#              ReLU-94          [-1, 512, 14, 14]               0
#            Conv2d-95          [-1, 512, 14, 14]          73,728
#       BatchNorm2d-96          [-1, 512, 14, 14]           1,024
#              ReLU-97          [-1, 512, 14, 14]               0
#            Conv2d-98         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-99         [-1, 1024, 14, 14]           2,048
#             ReLU-100         [-1, 1024, 14, 14]               0
#           Conv2d-101          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-102          [-1, 512, 14, 14]           1,024
#             ReLU-103          [-1, 512, 14, 14]               0
#           Conv2d-104          [-1, 512, 14, 14]          73,728
#      BatchNorm2d-105          [-1, 512, 14, 14]           1,024
#             ReLU-106          [-1, 512, 14, 14]               0
#           Conv2d-107         [-1, 1024, 14, 14]         524,288
#      BatchNorm2d-108         [-1, 1024, 14, 14]           2,048
#             ReLU-109         [-1, 1024, 14, 14]               0
#           Conv2d-110          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-111          [-1, 512, 14, 14]           1,024
#             ReLU-112          [-1, 512, 14, 14]               0
#           Conv2d-113          [-1, 512, 14, 14]          73,728
#      BatchNorm2d-114          [-1, 512, 14, 14]           1,024
#             ReLU-115          [-1, 512, 14, 14]               0
#           Conv2d-116         [-1, 1024, 14, 14]         524,288
#      BatchNorm2d-117         [-1, 1024, 14, 14]           2,048
#             ReLU-118         [-1, 1024, 14, 14]               0
#           Conv2d-119          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-120          [-1, 512, 14, 14]           1,024
#             ReLU-121          [-1, 512, 14, 14]               0
#           Conv2d-122          [-1, 512, 14, 14]          73,728
#      BatchNorm2d-123          [-1, 512, 14, 14]           1,024
#             ReLU-124          [-1, 512, 14, 14]               0
#           Conv2d-125         [-1, 1024, 14, 14]         524,288
#      BatchNorm2d-126         [-1, 1024, 14, 14]           2,048
#             ReLU-127         [-1, 1024, 14, 14]               0
#           Conv2d-128          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-129          [-1, 512, 14, 14]           1,024
#             ReLU-130          [-1, 512, 14, 14]               0
#           Conv2d-131          [-1, 512, 14, 14]          73,728
#      BatchNorm2d-132          [-1, 512, 14, 14]           1,024
#             ReLU-133          [-1, 512, 14, 14]               0
#           Conv2d-134         [-1, 1024, 14, 14]         524,288
#      BatchNorm2d-135         [-1, 1024, 14, 14]           2,048
#             ReLU-136         [-1, 1024, 14, 14]               0
#           Conv2d-137          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-138          [-1, 512, 14, 14]           1,024
#             ReLU-139          [-1, 512, 14, 14]               0
#           Conv2d-140          [-1, 512, 14, 14]          73,728
#      BatchNorm2d-141          [-1, 512, 14, 14]           1,024
#             ReLU-142          [-1, 512, 14, 14]               0
#           Conv2d-143         [-1, 1024, 14, 14]         524,288
#      BatchNorm2d-144         [-1, 1024, 14, 14]           2,048
#             ReLU-145         [-1, 1024, 14, 14]               0
#           Conv2d-146          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-147          [-1, 512, 14, 14]           1,024
#             ReLU-148          [-1, 512, 14, 14]               0
#           Conv2d-149          [-1, 512, 14, 14]          73,728
#      BatchNorm2d-150          [-1, 512, 14, 14]           1,024
#             ReLU-151          [-1, 512, 14, 14]               0
#           Conv2d-152         [-1, 1024, 14, 14]         524,288
#      BatchNorm2d-153         [-1, 1024, 14, 14]           2,048
#             ReLU-154         [-1, 1024, 14, 14]               0
#           Conv2d-155          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-156          [-1, 512, 14, 14]           1,024
#             ReLU-157          [-1, 512, 14, 14]               0
#           Conv2d-158          [-1, 512, 14, 14]          73,728
#      BatchNorm2d-159          [-1, 512, 14, 14]           1,024
#             ReLU-160          [-1, 512, 14, 14]               0
#           Conv2d-161         [-1, 1024, 14, 14]         524,288
#      BatchNorm2d-162         [-1, 1024, 14, 14]           2,048
#             ReLU-163         [-1, 1024, 14, 14]               0
#           Conv2d-164          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-165          [-1, 512, 14, 14]           1,024
#             ReLU-166          [-1, 512, 14, 14]               0
#           Conv2d-167          [-1, 512, 14, 14]          73,728
#      BatchNorm2d-168          [-1, 512, 14, 14]           1,024
#             ReLU-169          [-1, 512, 14, 14]               0
#           Conv2d-170         [-1, 1024, 14, 14]         524,288
#      BatchNorm2d-171         [-1, 1024, 14, 14]           2,048
#             ReLU-172         [-1, 1024, 14, 14]               0
#           Conv2d-173          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-174          [-1, 512, 14, 14]           1,024
#             ReLU-175          [-1, 512, 14, 14]               0
#           Conv2d-176          [-1, 512, 14, 14]          73,728
#      BatchNorm2d-177          [-1, 512, 14, 14]           1,024
#             ReLU-178          [-1, 512, 14, 14]               0
#           Conv2d-179         [-1, 1024, 14, 14]         524,288
#      BatchNorm2d-180         [-1, 1024, 14, 14]           2,048
#             ReLU-181         [-1, 1024, 14, 14]               0
#           Conv2d-182          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-183          [-1, 512, 14, 14]           1,024
#             ReLU-184          [-1, 512, 14, 14]               0
#           Conv2d-185          [-1, 512, 14, 14]          73,728
#      BatchNorm2d-186          [-1, 512, 14, 14]           1,024
#             ReLU-187          [-1, 512, 14, 14]               0
#           Conv2d-188         [-1, 1024, 14, 14]         524,288
#      BatchNorm2d-189         [-1, 1024, 14, 14]           2,048
#             ReLU-190         [-1, 1024, 14, 14]               0
#           Conv2d-191          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-192          [-1, 512, 14, 14]           1,024
#             ReLU-193          [-1, 512, 14, 14]               0
#           Conv2d-194          [-1, 512, 14, 14]          73,728
#      BatchNorm2d-195          [-1, 512, 14, 14]           1,024
#             ReLU-196          [-1, 512, 14, 14]               0
#           Conv2d-197         [-1, 1024, 14, 14]         524,288
#      BatchNorm2d-198         [-1, 1024, 14, 14]           2,048
#             ReLU-199         [-1, 1024, 14, 14]               0
#           Conv2d-200          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-201          [-1, 512, 14, 14]           1,024
#             ReLU-202          [-1, 512, 14, 14]               0
#           Conv2d-203          [-1, 512, 14, 14]          73,728
#      BatchNorm2d-204          [-1, 512, 14, 14]           1,024
#             ReLU-205          [-1, 512, 14, 14]               0
#           Conv2d-206         [-1, 1024, 14, 14]         524,288
#      BatchNorm2d-207         [-1, 1024, 14, 14]           2,048
#             ReLU-208         [-1, 1024, 14, 14]               0
#           Conv2d-209          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-210          [-1, 512, 14, 14]           1,024
#             ReLU-211          [-1, 512, 14, 14]               0
#           Conv2d-212          [-1, 512, 14, 14]          73,728
#      BatchNorm2d-213          [-1, 512, 14, 14]           1,024
#             ReLU-214          [-1, 512, 14, 14]               0
#           Conv2d-215         [-1, 1024, 14, 14]         524,288
#      BatchNorm2d-216         [-1, 1024, 14, 14]           2,048
#             ReLU-217         [-1, 1024, 14, 14]               0
#           Conv2d-218          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-219          [-1, 512, 14, 14]           1,024
#             ReLU-220          [-1, 512, 14, 14]               0
#           Conv2d-221          [-1, 512, 14, 14]          73,728
#      BatchNorm2d-222          [-1, 512, 14, 14]           1,024
#             ReLU-223          [-1, 512, 14, 14]               0
#           Conv2d-224         [-1, 1024, 14, 14]         524,288
#      BatchNorm2d-225         [-1, 1024, 14, 14]           2,048
#             ReLU-226         [-1, 1024, 14, 14]               0
#           Conv2d-227          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-228          [-1, 512, 14, 14]           1,024
#             ReLU-229          [-1, 512, 14, 14]               0
#           Conv2d-230          [-1, 512, 14, 14]          73,728
#      BatchNorm2d-231          [-1, 512, 14, 14]           1,024
#             ReLU-232          [-1, 512, 14, 14]               0
#           Conv2d-233         [-1, 1024, 14, 14]         524,288
#      BatchNorm2d-234         [-1, 1024, 14, 14]           2,048
#             ReLU-235         [-1, 1024, 14, 14]               0
#           Conv2d-236          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-237          [-1, 512, 14, 14]           1,024
#             ReLU-238          [-1, 512, 14, 14]               0
#           Conv2d-239          [-1, 512, 14, 14]          73,728
#      BatchNorm2d-240          [-1, 512, 14, 14]           1,024
#             ReLU-241          [-1, 512, 14, 14]               0
#           Conv2d-242         [-1, 1024, 14, 14]         524,288
#      BatchNorm2d-243         [-1, 1024, 14, 14]           2,048
#             ReLU-244         [-1, 1024, 14, 14]               0
#           Conv2d-245          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-246          [-1, 512, 14, 14]           1,024
#             ReLU-247          [-1, 512, 14, 14]               0
#           Conv2d-248          [-1, 512, 14, 14]          73,728
#      BatchNorm2d-249          [-1, 512, 14, 14]           1,024
#             ReLU-250          [-1, 512, 14, 14]               0
#           Conv2d-251         [-1, 1024, 14, 14]         524,288
#      BatchNorm2d-252         [-1, 1024, 14, 14]           2,048
#             ReLU-253         [-1, 1024, 14, 14]               0
#           Conv2d-254          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-255          [-1, 512, 14, 14]           1,024
#             ReLU-256          [-1, 512, 14, 14]               0
#           Conv2d-257          [-1, 512, 14, 14]          73,728
#      BatchNorm2d-258          [-1, 512, 14, 14]           1,024
#             ReLU-259          [-1, 512, 14, 14]               0
#           Conv2d-260         [-1, 1024, 14, 14]         524,288
#      BatchNorm2d-261         [-1, 1024, 14, 14]           2,048
#             ReLU-262         [-1, 1024, 14, 14]               0
#           Conv2d-263          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-264          [-1, 512, 14, 14]           1,024
#             ReLU-265          [-1, 512, 14, 14]               0
#           Conv2d-266          [-1, 512, 14, 14]          73,728
#      BatchNorm2d-267          [-1, 512, 14, 14]           1,024
#             ReLU-268          [-1, 512, 14, 14]               0
#           Conv2d-269         [-1, 1024, 14, 14]         524,288
#      BatchNorm2d-270         [-1, 1024, 14, 14]           2,048
#             ReLU-271         [-1, 1024, 14, 14]               0
#           Conv2d-272          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-273          [-1, 512, 14, 14]           1,024
#             ReLU-274          [-1, 512, 14, 14]               0
#           Conv2d-275          [-1, 512, 14, 14]          73,728
#      BatchNorm2d-276          [-1, 512, 14, 14]           1,024
#             ReLU-277          [-1, 512, 14, 14]               0
#           Conv2d-278         [-1, 1024, 14, 14]         524,288
#      BatchNorm2d-279         [-1, 1024, 14, 14]           2,048
#             ReLU-280         [-1, 1024, 14, 14]               0
#           Conv2d-281         [-1, 1024, 14, 14]       1,048,576
#      BatchNorm2d-282         [-1, 1024, 14, 14]           2,048
#             ReLU-283         [-1, 1024, 14, 14]               0
#           Conv2d-284           [-1, 1024, 7, 7]         294,912
#      BatchNorm2d-285           [-1, 1024, 7, 7]           2,048
#             ReLU-286           [-1, 1024, 7, 7]               0
#           Conv2d-287           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-288           [-1, 2048, 7, 7]           4,096
#           Conv2d-289           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-290           [-1, 2048, 7, 7]           4,096
#             ReLU-291           [-1, 2048, 7, 7]               0
#           Conv2d-292           [-1, 1024, 7, 7]       2,097,152
#      BatchNorm2d-293           [-1, 1024, 7, 7]           2,048
#             ReLU-294           [-1, 1024, 7, 7]               0
#           Conv2d-295           [-1, 1024, 7, 7]         294,912
#      BatchNorm2d-296           [-1, 1024, 7, 7]           2,048
#             ReLU-297           [-1, 1024, 7, 7]               0
#           Conv2d-298           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-299           [-1, 2048, 7, 7]           4,096
#             ReLU-300           [-1, 2048, 7, 7]               0
#           Conv2d-301           [-1, 1024, 7, 7]       2,097,152
#      BatchNorm2d-302           [-1, 1024, 7, 7]           2,048
#             ReLU-303           [-1, 1024, 7, 7]               0
#           Conv2d-304           [-1, 1024, 7, 7]         294,912
#      BatchNorm2d-305           [-1, 1024, 7, 7]           2,048
#             ReLU-306           [-1, 1024, 7, 7]               0
#           Conv2d-307           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-308           [-1, 2048, 7, 7]           4,096
#             ReLU-309           [-1, 2048, 7, 7]               0
# ================================================================
# Total params: 42,128,704
# Trainable params: 42,128,704
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 475.84
# Params size (MB): 160.71
# Estimated Total Size (MB): 637.12
# ----------------------------------------------------------------

# %%
torch.nn.functional.max_pool2d
torch.nn.functional.adaptive_avg_pool2d()

# %%
# torch.nn.Dropout?

class Flatten(nn.Module):
    def forward(self, x):
        return x.view(x.size()[0], -1)

# %%
model = pretrainedmodels.__dict__[model_name](num_classes=1000, pretrained="imagenet")
backbone = model.features
classifier = nn.Sequential(
        nn.AdaptiveAvgPool2d((1, 1)),
        Flatten(),
        nn.Dropout(0.5),
        nn.Linear(in_features=1056, out_features=1, bias=True)
        )

# %%
img = torch.Tensor(1, 3, 112, 112)
features = backbone(img)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-38-816786b01ed4> in <module>
#       1 img = torch.Tensor(1, 3, 112, 112)
# ----> 2 features = backbone(img)
#
# ~/miniconda3/envs/ML/lib/python3.7/site-packages/pretrainedmodels/models/nasnet_mobile.py in features(self, input)
#     596         x_reduction_cell_1 = self.reduction_cell_1(x_cell_9, x_cell_8)
#     597
# --> 598         x_cell_12 = self.cell_12(x_reduction_cell_1, x_cell_9)
#     599         x_cell_13 = self.cell_13(x_cell_12, x_reduction_cell_1)
#     600         x_cell_14 = self.cell_14(x_cell_13, x_cell_12)
#
# ~/miniconda3/envs/ML/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/ML/lib/python3.7/site-packages/pretrainedmodels/models/nasnet_mobile.py in forward(self, x, x_prev)
#     332         x_comb_iter_0_left = self.comb_iter_0_left(x_right)
#     333         x_comb_iter_0_right = self.comb_iter_0_right(x_left)
# --> 334         x_comb_iter_0 = x_comb_iter_0_left + x_comb_iter_0_right
#     335
#     336         x_comb_iter_1_left = self.comb_iter_1_left(x_left)
#
# RuntimeError: The size of tensor a (3) must match the size of tensor b (4) at non-singleton dimension 3

# %%
model.parameters()
# Out:
# <generator object Module.parameters at 0x7f961f946a20>

# %%
 
from albumentations import *

# %%
train_aug = Compose([
    Resize(224, 224),
    RandomRotate90(p=0.5),
    Transpose(p=0.5),
    Flip(p=0.5),
    OneOf([CLAHE(clip_limit=2), IAASharpen(), IAAEmboss(), RandomBrightnessContrast(), JpegCompression(), Blur(), GaussNoise() ], p=0.5), 
    HueSaturationValue(p=0.5), 
    ShiftScaleRotate(shift_limit=0.15, scale_limit=0.15, rotate_limit=45, p=0.5),
    Normalize(p=1)
])
val_aug = Compose([
    Normalize(p=1)
])

# %%
ShiftScaleRotate?

# %%
Normalize?

# %%
train_aug?

# %%
flip = Flip(p=1)

# %%
flip.apply?

# %% [markdown]
# ##### AUC ROC

# %%
# roc curve and auc
from sklearn.datasets import make_classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot
# generate 2 class dataset
X, y = make_classification(n_samples=1000, n_classes=2, weights=[1,1], random_state=1)
# split into train/test sets
trainX, testX, trainy, testy = train_test_split(X, y, test_size=0.5, random_state=2)
# fit a model
model = KNeighborsClassifier(n_neighbors=3)
model.fit(trainX, trainy)
# predict probabilities
probs = model.predict_proba(testX)
# keep probabilities for the positive outcome only
probs = probs[:, 1]

# %%
testy.shape, probs.shape

# %%
fpr, tpr, thresholds

# %%
# calculate AUC
auc = roc_auc_score(testy, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(testy, probs)
# plot no skill
pyplot.plot([0, 1], [0, 1], linestyle='--')
pyplot.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
pyplot.plot(fpr, tpr, marker='.')
# show the plot
pyplot.show()

# %%
pyplot.savefig('lol.png')

# %%
pyplot.close('all')

# %%
import apex

# %%
apex.amp.?

# %%
import pandas as pd
df1 = pd.read_csv('weights/ensemble/11Mar_nasnetamobile_fold0_ckpt17.csv')
df2 = pd.read_csv('weights/ensemble/9Mar_se_resnext50_32x4d_v3_fold0_1_2_allckpt17.csv')
df3 = pd.read_csv('weights/ensemble/11Mar_nasnetamobile_v2_fold2_ckpt20.csv')
df= df1.copy()
df['label'] = (df1['label'] + df3['label'] + 3* df2['label'])/5

# %%
df.head()
# Out:
#                                          id     label
# 0  0b2ea2a822ad23fdb1b5dd26653da899fbd2c0d5  0.027841
# 1  95596b92e5066c5c52466c90b69ff089b39f2737  0.056335
# 2  248e6738860e2ebcf6258cdc1f32f299e0c76914  0.001182
# 3  2c35657e312966e9294eac6841726ff3a748febf  0.005621
# 4  145782eb7caa1c516acbe2eda34d9a3f31c41fd6  0.028158

# %%
df.to_csv('weights/ensemble/resnextfold012ckpt17+nasnetmobileckpt17+nasnetamobilefold2_ckpt20.csv', index=False)
