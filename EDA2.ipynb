# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

# %%
train.head()
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %%
train[['diagnosis']].astype('int')
# Out:
#       diagnosis
# 0             2
# 1             4
# 2             1
# 3             0
# 4             0
# 5             4
# 6             0
# 7             2
# 8             2
# 9             1
# 10            0
# 11            2
# 12            0
# 13            3
# 14            1
# 15            0
# 16            2
# 17            0
# 18            0
# 19            2
# 20            2
# 21            0
# 22            1
# 23            2
# 24            0
# 25            2
# 26            0
# 27            0
# 28            0
# 29            0
# ...         ...
# 3632          0
# 3633          0
# 3634          3
# 3635          1
# 3636          2
# 3637          0
# 3638          0
# 3639          1
# 3640          1
# 3641          0
# 3642          1
# 3643          0
# 3644          0
# 3645          0
# 3646          2
# 3647          0
# 3648          2
# 3649          0
# 3650          0
# 3651          0
# 3652          2
# 3653          0
# 3654          0
# ...

# %%
train['diagnosis'].value_counts().plot(kind='bar');

# %%
train.diagnosis.dtype
# Out:
# dtype('int64')

# %%
test.head()
# Out:
#         id_code
# 0  0005cfc8afb6
# 1  003f0afdcd15
# 2  006efc72b638
# 3  00836aaacf06
# 4  009245722fa4
